# %%
# Importar los nuevos algoritmos implementados
from agents.mcts_t import MonteCarloTreeSearch
from agents.counterfactualregret_t import CounterFactualRegret
import numpy as np

# %%
from games.nocca_nocca.nocca_nocca import NoccaNocca
from agents.agent_random import RandomAgent
from agents.minimax import MiniMax

# %%
game = NoccaNocca(max_steps=150, initial_player=0, seed=1)

# %%
agents = {
    game.agents[0]: MiniMax(game=game, agent=game.agents[0], depth=1),
    game.agents[1]: MiniMax(game=game, agent=game.agents[1], depth=1),
}

# %%
game.reset()
print(f"Initial Agent: {game.agent_selection}")
while not game.game_over():
    game.render()
    action = agents[game.agent_selection].action()
    print(f"Turn {game.steps} -- Agent {game.agent_selection} plays action {action}")
    game.step(action=action)
game.render()
if game.truncated():
    print("Game was truncated")
for agent in agents:
    print(f"Reward agent {agent}: {game.reward(agent)}")
print(f"The winner is: {game.check_for_winner()}")
# Out:
# Initial Agent: Black
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ 0__ 0__ 0__
# 2: ___ ___ ___ ___ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ 1__ 1__ 1__
# 7: ___ ___ ___ ___ ___
# Turn 0 -- Agent Black plays action 57
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ ___ 0__ 0__
# 2: ___ ___ 0__ ___ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ 1__ 1__ 1__
# 7: ___ ___ ___ ___ ___
# Turn 1 -- Agent White plays action 274
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ ___ 0__ 0__
# 2: ___ ___ 0__ ___ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ 1__ 11_ ___
# 7: ___ ___ ___ ___ ___
# Turn 2 -- Agent Black plays action 103
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ ___ 00_ 0__
# 2: ___ ___ ___ ___ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ 1__ 11_ ___
# 7: ___ ___ ___ ___ ___
# Turn 3 -- Agent White plays action 267
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ ___ 00_ 0__
# 2: ___ ___ ___ ___ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ 1__ 1__ 1__
# 7: ___ ___ ___ ___ ___
# Turn 4 -- Agent Black plays action 70
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ ___ 0__ 0__
# 2: ___ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ 1__ 1__ 1__
# 7: ___ ___ ___ ___ ___
# Turn 5 -- Agent White plays action 261
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ ___ 0__ 0__
# 2: ___ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ 1__ ___ ___ ___
# 6: 1__ 1__ ___ 1__ 1__
# 7: ___ ___ ___ ___ ___
# Turn 6 -- Agent Black plays action 41
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ ___ 0__ 0__
# 2: 0__ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ 1__ ___ ___ ___
# 6: 1__ 1__ ___ 1__ 1__
# 7: ___ ___ ___ ___ ___
# Turn 7 -- Agent White plays action 208
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ ___ 0__ 0__
# 2: 0__ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ ___ 1__ 1__
# 7: ___ ___ ___ ___ ___
# Turn 8 -- Agent Black plays action 68
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ ___ ___ 0__
# 2: 0__ ___ 0__ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ ___ 1__ 1__
# 7: ___ ___ ___ ___ ___
# Turn 9 -- Agent White plays action 250
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ ___ ___ 0__
# 2: 0__ ___ 0__ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: 11_ ___ ___ 1__ 1__
# 7: ___ ___ ___ ___ ___
# Turn 10 -- Agent Black plays action 101
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ 0__
# 2: 0__ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ ___ ___
# 6: 11_ ___ ___ 1__ 1__
# 7: ___ ___ ___ ___ ___
# Turn 11 -- Agent White plays action 264
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ 0__
# 2: 0__ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ 1__ ___
# 6: 11_ ___ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 12 -- Agent Black plays action 51
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 0__ ___ 0__
# 2: 0__ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ 1__ ___
# 6: 11_ ___ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 13 -- Agent White plays action 174
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 0__ ___ 0__
# 2: 0__ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ 1__ 1__ ___
# 6: 11_ ___ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 14 -- Agent Black plays action 80
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ 0__ ___ 0__
# 2: ___ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ 1__ 1__ ___
# 6: 11_ ___ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 15 -- Agent White plays action 240
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ 0__ ___ 0__
# 2: ___ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: 1__ ___ 1__ 1__ ___
# 6: 1__ ___ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 16 -- Agent Black plays action 74
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ 0__ 0__ ___
# 2: ___ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: 1__ ___ 1__ 1__ ___
# 6: 1__ ___ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 17 -- Agent White plays action 201
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ 0__ 0__ ___
# 2: ___ ___ ___ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ 1__ 1__ ___
# 6: 11_ ___ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 18 -- Agent Black plays action 68
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ 0__ ___ ___
# 2: ___ ___ 0__ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ 1__ 1__ ___
# 6: 11_ ___ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 19 -- Agent White plays action 272
# 0: ___ ___ ___ ___ ___
# 1: 0__ 0__ 0__ ___ ___
# 2: ___ ___ 0__ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ 1__ 1__ 1__
# 6: 11_ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 20 -- Agent Black plays action 46
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 0__ ___ ___
# 2: ___ 0__ 0__ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ 1__ 1__ 1__
# 6: 11_ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 21 -- Agent White plays action 243
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 0__ ___ ___
# 2: ___ 0__ 0__ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ 1__ 1__ 1__
# 6: 1__ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 22 -- Agent Black plays action 100
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 0__ ___ ___
# 2: ___ 0__ ___ ___ 0__
# 3: ___ 0__ ___ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: ___ ___ 1__ 1__ 1__
# 6: 1__ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 23 -- Agent White plays action 221
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 0__ ___ ___
# 2: ___ 0__ ___ ___ 0__
# 3: ___ 0__ ___ ___ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ 1__ 1__
# 6: 1__ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 24 -- Agent Black plays action 58
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ 0__ ___ ___ 0__
# 3: ___ 0__ ___ ___ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ 1__ 1__
# 6: 1__ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 25 -- Agent White plays action 227
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ 0__ ___ ___ 0__
# 3: ___ 0__ ___ ___ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ ___ 11_
# 6: 1__ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 26 -- Agent Black plays action 131
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ 0__ ___ ___ 0__
# 3: ___ ___ 0__ ___ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ ___ 11_
# 6: 1__ 1__ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 27 -- Agent White plays action 233
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ 0__ ___ ___ 0__
# 3: ___ ___ 0__ ___ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ ___ 1__
# 6: 1__ 1__ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 28 -- Agent Black plays action 138
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ 0__ ___ ___ 0__
# 3: ___ 0__ ___ ___ ___
# 4: ___ 1__ ___ ___ ___
# 5: ___ ___ ___ ___ 1__
# 6: 1__ 1__ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 29 -- Agent White plays action 232
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ 0__ ___ ___ 0__
# 3: ___ 0__ ___ ___ ___
# 4: ___ 1__ ___ ___ 1__
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 30 -- Agent Black plays action 135
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ 0__ 0__ ___ 0__
# 3: ___ ___ ___ ___ ___
# 4: ___ 1__ ___ ___ 1__
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 31 -- Agent White plays action 175
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ 0__ 0__ ___ 0__
# 3: ___ ___ 1__ ___ ___
# 4: ___ ___ ___ ___ 1__
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 32 -- Agent Black plays action 94
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ ___ 0__ ___ 0__
# 3: ___ ___ 10_ ___ ___
# 4: ___ ___ ___ ___ 1__
# 5: ___ ___ ___ ___ ___
# 6: 1__ 1__ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 33 -- Agent White plays action 248
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ ___ 0__ ___ 0__
# 3: ___ ___ 10_ ___ ___
# 4: ___ ___ ___ ___ 1__
# 5: ___ 1__ ___ ___ ___
# 6: 1__ ___ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 34 -- Agent Black plays action 113
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ ___ 0__ ___ ___
# 3: ___ ___ 10_ ___ 0__
# 4: ___ ___ ___ ___ 1__
# 5: ___ 1__ ___ ___ ___
# 6: 1__ ___ ___ ___ 1__
# 7: ___ ___ ___ ___ ___
# Turn 35 -- Agent White plays action 272
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ ___ 0__ ___ ___
# 3: ___ ___ 10_ ___ 0__
# 4: ___ ___ ___ ___ 1__
# 5: ___ 1__ ___ ___ 1__
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 36 -- Agent Black plays action 152
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ ___ 0__ ___ 0__
# 3: ___ ___ 10_ ___ ___
# 4: ___ ___ ___ ___ 1__
# 5: ___ 1__ ___ ___ 1__
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 37 -- Agent White plays action 208
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ ___ 0__ ___ 0__
# 3: ___ ___ 10_ ___ ___
# 4: ___ 1__ ___ ___ 1__
# 5: ___ ___ ___ ___ 1__
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 38 -- Agent Black plays action 143
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ ___ 0__ 0__ 0__
# 3: ___ ___ 1__ ___ ___
# 4: ___ 1__ ___ ___ 1__
# 5: ___ ___ ___ ___ 1__
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 39 -- Agent White plays action 232
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ ___ 0__ 0__ 0__
# 3: ___ ___ 1__ ___ ___
# 4: ___ 1__ ___ ___ 11_
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 40 -- Agent Black plays action 113
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ ___ 0__ 0__ ___
# 3: ___ ___ 1__ ___ 0__
# 4: ___ 1__ ___ ___ 11_
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 41 -- Agent White plays action 171
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ ___ 0__ 0__ ___
# 3: ___ ___ 1__ ___ 0__
# 4: ___ ___ 1__ ___ 11_
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 42 -- Agent Black plays action 153
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ ___ 0__ 0__ ___
# 3: ___ ___ 1__ ___ ___
# 4: ___ ___ 1__ ___ 110
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 43 -- Agent White plays action 139
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ ___ 0__ 0__ ___
# 3: ___ ___ ___ 1__ ___
# 4: ___ ___ 1__ ___ 110
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 44 -- Agent Black plays action 99
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ ___ ___ 00_ ___
# 3: ___ ___ ___ 1__ ___
# 4: ___ ___ 1__ ___ 110
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 45 -- Agent White plays action 150
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ ___ ___ ___
# 2: ___ ___ ___ 00_ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ 1__ ___ 111
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 46 -- Agent Black plays action 109
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ 0__ ___ ___
# 2: ___ ___ ___ 0__ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ 1__ ___ 111
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 47 -- Agent White plays action 196
# 0: ___ ___ ___ ___ ___
# 1: ___ 00_ 0__ ___ ___
# 2: ___ ___ ___ 0__ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ 1__ ___ 11_
# 5: ___ ___ ___ 1__ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 48 -- Agent Black plays action 49
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 0__ ___ ___
# 2: ___ 0__ ___ 0__ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ 1__ ___ 11_
# 5: ___ ___ ___ 1__ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 49 -- Agent White plays action 229
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 0__ ___ ___
# 2: ___ 0__ ___ 0__ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ 11_ ___ 11_
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 50 -- Agent Black plays action 109
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 00_ ___ ___
# 2: ___ 0__ ___ ___ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ 11_ ___ 11_
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 51 -- Agent White plays action 180
# 0: ___ ___ ___ ___ ___
# 1: ___ 0__ 00_ ___ ___
# 2: ___ 0__ ___ ___ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ 1__ ___ 11_
# 5: ___ 1__ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 52 -- Agent Black plays action 50
# 0: ___ ___ ___ ___ ___
# 1: 0__ ___ 00_ ___ ___
# 2: ___ 0__ ___ ___ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ 1__ ___ 11_
# 5: ___ 1__ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 53 -- Agent White plays action 215
# 0: ___ ___ ___ ___ ___
# 1: 0__ ___ 00_ ___ ___
# 2: ___ 0__ ___ ___ ___
# 3: ___ ___ ___ ___ ___
# 4: ___ ___ 11_ ___ 11_
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 54 -- Agent Black plays action 92
# 0: ___ ___ ___ ___ ___
# 1: 0__ ___ 00_ ___ ___
# 2: ___ ___ ___ ___ ___
# 3: 0__ ___ ___ ___ ___
# 4: ___ ___ 11_ ___ 11_
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 55 -- Agent White plays action 179
# 0: ___ ___ ___ ___ ___
# 1: 0__ ___ 00_ ___ ___
# 2: ___ ___ ___ ___ ___
# 3: 0__ ___ ___ ___ ___
# 4: ___ ___ 1__ 1__ 11_
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 56 -- Agent Black plays action 57
# 0: ___ ___ ___ ___ ___
# 1: 0__ ___ 0__ ___ ___
# 2: ___ ___ 0__ ___ ___
# 3: 0__ ___ ___ ___ ___
# 4: ___ ___ 1__ 1__ 11_
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 57 -- Agent White plays action 188
# 0: ___ ___ ___ ___ ___
# 1: 0__ ___ 0__ ___ ___
# 2: ___ ___ 0__ ___ ___
# 3: 0__ ___ ___ ___ ___
# 4: ___ ___ 1__ ___ 11_
# 5: ___ ___ 1__ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 58 -- Agent Black plays action 46
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ 0__ ___ ___
# 2: ___ 0__ 0__ ___ ___
# 3: 0__ ___ ___ ___ ___
# 4: ___ ___ 1__ ___ 11_
# 5: ___ ___ 1__ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 59 -- Agent White plays action 216
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ 0__ ___ ___
# 2: ___ 0__ 0__ ___ ___
# 3: 0__ ___ ___ ___ ___
# 4: ___ ___ 11_ ___ 11_
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 60 -- Agent Black plays action 57
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ 0__ 00_ ___ ___
# 3: 0__ ___ ___ ___ ___
# 4: ___ ___ 11_ ___ 11_
# 5: ___ ___ ___ ___ ___
# 6: 1__ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 61 -- Agent White plays action 240
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ 0__ 00_ ___ ___
# 3: 0__ ___ ___ ___ ___
# 4: ___ ___ 11_ ___ 11_
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 62 -- Agent Black plays action 92
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ ___ 00_ ___ ___
# 3: 00_ ___ ___ ___ ___
# 4: ___ ___ 11_ ___ 11_
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 63 -- Agent White plays action 192
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ ___ 00_ ___ ___
# 3: 00_ ___ ___ ___ 1__
# 4: ___ ___ 11_ ___ 1__
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 64 -- Agent Black plays action 98
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ 0__ 0__ ___ ___
# 3: 00_ ___ ___ ___ 1__
# 4: ___ ___ 11_ ___ 1__
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 65 -- Agent White plays action 177
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ 0__ 0__ ___ ___
# 3: 00_ ___ ___ ___ 1__
# 4: ___ ___ 1__ ___ 1__
# 5: 1__ ___ 1__ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 66 -- Agent Black plays action 121
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ 0__ 0__ ___ ___
# 3: 0__ ___ ___ ___ 1__
# 4: 0__ ___ 1__ ___ 1__
# 5: 1__ ___ 1__ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 67 -- Agent White plays action 183
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ 0__ 0__ ___ ___
# 3: 0__ ___ ___ 1__ 1__
# 4: 0__ ___ ___ ___ 1__
# 5: 1__ ___ 1__ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 68 -- Agent Black plays action 94
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ ___ 0__ ___ ___
# 3: 0__ ___ 0__ 1__ 1__
# 4: 0__ ___ ___ ___ 1__
# 5: 1__ ___ 1__ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 69 -- Agent White plays action 146
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ ___ 0__ ___ ___
# 3: 0__ ___ 01_ ___ 1__
# 4: 0__ ___ ___ ___ 1__
# 5: 1__ ___ 1__ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 70 -- Agent Black plays action 100
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ ___ ___ ___ ___
# 3: 0__ 0__ 01_ ___ 1__
# 4: 0__ ___ ___ ___ 1__
# 5: 1__ ___ 1__ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 71 -- Agent White plays action 194
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ ___ ___ ___ ___
# 3: 0__ 0__ 01_ ___ 1__
# 4: 0__ ___ ___ 1__ ___
# 5: 1__ ___ 1__ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 72 -- Agent Black plays action 163
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ ___ ___ ___ ___
# 3: 0__ 0__ 01_ ___ 1__
# 4: ___ 0__ ___ 1__ ___
# 5: 1__ ___ 1__ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 73 -- Agent White plays action 156
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ ___ ___ ___ ___
# 3: 0__ 0__ 01_ ___ ___
# 4: ___ 0__ ___ 11_ ___
# 5: 1__ ___ 1__ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 74 -- Agent Black plays action 172
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ ___ ___ ___ ___
# 3: 0__ 0__ 01_ ___ ___
# 4: ___ ___ ___ 11_ ___
# 5: 10_ ___ 1__ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 75 -- Agent White plays action 216
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ ___ ___ ___ ___
# 3: 0__ 0__ 01_ ___ ___
# 4: ___ ___ 1__ 11_ ___
# 5: 10_ ___ ___ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 76 -- Agent Black plays action 207
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ ___ ___ ___ ___
# 3: 0__ 0__ 01_ ___ ___
# 4: ___ 0__ 1__ 11_ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 77 -- Agent White plays action 141
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ 1__ ___ ___ ___
# 3: 0__ 0__ 0__ ___ ___
# 4: ___ 0__ 1__ 11_ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 78 -- Agent Black plays action 133
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: 0__ 1__ ___ ___ ___
# 3: 0__ ___ 0__ ___ ___
# 4: ___ 0__ 1__ 11_ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 79 -- Agent White plays action 190
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: 0__ 1__ ___ ___ ___
# 3: 0__ ___ 0__ ___ ___
# 4: ___ 0__ 1__ 1__ ___
# 5: 1__ ___ ___ ___ 1__
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 80 -- Agent Black plays action 173
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: 0__ 1__ ___ ___ ___
# 3: 00_ ___ 0__ ___ ___
# 4: ___ ___ 1__ 1__ ___
# 5: 1__ ___ ___ ___ 1__
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 81 -- Agent White plays action 176
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: 0__ 1__ ___ ___ ___
# 3: 00_ ___ 01_ ___ ___
# 4: ___ ___ ___ 1__ ___
# 5: 1__ ___ ___ ___ 1__
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 82 -- Agent Black plays action 127
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: 0__ 10_ ___ ___ ___
# 3: 0__ ___ 01_ ___ ___
# 4: ___ ___ ___ 1__ ___
# 5: 1__ ___ ___ ___ 1__
# 6: ___ ___ ___ ___ ___
# 7: ___ ___ ___ ___ ___
# Turn 83 -- Agent White plays action 236
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: 0__ 10_ ___ ___ ___
# 3: 0__ ___ 01_ ___ ___
# 4: ___ ___ ___ 1__ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ 1__ ___
# 7: ___ ___ ___ ___ ___
# Turn 84 -- Agent Black plays action 81
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ 10_ ___ ___ ___
# 3: 00_ ___ 01_ ___ ___
# 4: ___ ___ ___ 1__ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ 1__ ___
# 7: ___ ___ ___ ___ ___
# Turn 85 -- Agent White plays action 188
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ 10_ ___ ___ ___
# 3: 00_ ___ 01_ ___ ___
# 4: ___ ___ ___ ___ ___
# 5: 1__ ___ 1__ ___ ___
# 6: ___ ___ ___ 1__ ___
# 7: ___ ___ ___ ___ ___
# Turn 86 -- Agent Black plays action 121
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ 10_ ___ ___ ___
# 3: 0__ ___ 01_ ___ ___
# 4: 0__ ___ ___ ___ ___
# 5: 1__ ___ 1__ ___ ___
# 6: ___ ___ ___ 1__ ___
# 7: ___ ___ ___ ___ ___
# Turn 87 -- Agent White plays action 221
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ 10_ ___ ___ ___
# 3: 0__ ___ 01_ ___ ___
# 4: 0__ 1__ ___ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ 1__ ___
# 7: ___ ___ ___ ___ ___
# Turn 88 -- Agent Black plays action 163
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ 10_ ___ ___ ___
# 3: 0__ ___ 01_ ___ ___
# 4: ___ 10_ ___ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ 1__ ___
# 7: ___ ___ ___ ___ ___
# Turn 89 -- Agent White plays action 143
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ 10_ ___ 1__ ___
# 3: 0__ ___ 0__ ___ ___
# 4: ___ 10_ ___ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ 1__ ___
# 7: ___ ___ ___ ___ ___
# Turn 90 -- Agent Black plays action 127
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ ___ ___ ___
# 2: ___ 100 ___ 1__ ___
# 3: ___ ___ 0__ ___ ___
# 4: ___ 10_ ___ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ 1__ ___
# 7: ___ ___ ___ ___ ___
# Turn 91 -- Agent White plays action 109
# 0: ___ ___ ___ ___ ___
# 1: ___ ___ 1__ ___ ___
# 2: ___ 100 ___ ___ ___
# 3: ___ ___ 0__ ___ ___
# 4: ___ 10_ ___ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ 1__ ___
# 7: ___ ___ ___ ___ ___
# Turn 92 -- Agent Black plays action 93
# 0: ___ ___ ___ ___ ___
# 1: 0__ ___ 1__ ___ ___
# 2: ___ 10_ ___ ___ ___
# 3: ___ ___ 0__ ___ ___
# 4: ___ 10_ ___ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ 1__ ___
# 7: ___ ___ ___ ___ ___
# Turn 93 -- Agent White plays action 63
# 0: ___ ___ ___ 1__ ___
# 1: 0__ ___ ___ ___ ___
# 2: ___ 10_ ___ ___ ___
# 3: ___ ___ 0__ ___ ___
# 4: ___ 10_ ___ ___ ___
# 5: 1__ ___ ___ ___ ___
# 6: ___ ___ ___ 1__ ___
# 7: ___ ___ ___ ___ ___
# Reward agent Black: -1
# Reward agent White: 1
# The winner is: White

# %%
# Prueba rápida de MCTS en Nocca-Nocca
print("=== Probando MCTS en Nocca-Nocca ===")
game_mcts = NoccaNocca(max_steps=150, initial_player=0, seed=1)

# Crear agentes MCTS con pocas simulaciones para prueba rápida
agents_mcts = {
    game_mcts.agents[0]: MonteCarloTreeSearch(game=game_mcts, agent=game_mcts.agents[0], simulations=10),
    game_mcts.agents[1]: MonteCarloTreeSearch(game=game_mcts, agent=game_mcts.agents[1], simulations=10)
}

game_mcts.reset()
print(f"Initial Agent: {game_mcts.agent_selection}")
step_count = 0
while not game_mcts.game_over() and step_count < 50:  # Límite para evitar juegos muy largos
    try:
        action = agents_mcts[game_mcts.agent_selection].action()
        print(f"Turn {game_mcts.steps} -- Agent {game_mcts.agent_selection} plays action {action}")
        game_mcts.step(action=action)
        step_count += 1
    except Exception as e:
        print(f"Error: {e}")
        # Usar acción aleatoria como fallback
        available = game_mcts.available_actions()
        if available:
            action = np.random.choice(available)
            game_mcts.step(action)
            step_count += 1
        else:
            break

if game_mcts.truncated():
    print("Game was truncated")
for agent in agents_mcts:
    print(f"Reward agent {agent}: {game_mcts.reward(agent)}")
print(f"The winner is: {game_mcts.check_for_winner()}")
print("MCTS test completed!")

# %%
# Comparación de rendimiento entre algoritmos
print("\n=== Comparación de Algoritmos en Nocca-Nocca ===")

def test_algorithm_performance(game_class, agent_class, agent_kwargs, episodes=5):
    """Prueba el rendimiento de un algoritmo"""
    wins = 0
    total_steps = 0
    
    for episode in range(episodes):
        game = game_class(max_steps=100, seed=episode)
        agents = {}
        for agent_id in game.agents:
            agents[agent_id] = agent_class(game=game, agent=agent_id, **agent_kwargs)
        
        game.reset()
        steps = 0
        while not game.game_over() and steps < 100:
            try:
                action = agents[game.agent_selection].action()
                game.step(action)
                steps += 1
            except:
                available = game.available_actions()
                if available:
                    action = np.random.choice(available)
                    game.step(action)
                    steps += 1
                else:
                    break
        
        total_steps += steps
        if hasattr(game, 'check_for_winner'):
            winner = game.check_for_winner()
            if winner:
                wins += 1
    
    avg_steps = total_steps / episodes
    return wins, avg_steps

# Probar diferentes algoritmos
print("\nMiniMax:")
minimax_wins, minimax_steps = test_algorithm_performance(
    NoccaNocca, MiniMax, {'depth': 1}, episodes=5
)
print(f"  Wins: {minimax_wins}/5, Avg steps: {minimax_steps:.1f}")

print("\nMCTS:")
mcts_wins, mcts_steps = test_algorithm_performance(
    NoccaNocca, MonteCarloTreeSearch, {'simulations': 10}, episodes=5
)
print(f"  Wins: {mcts_wins}/5, Avg steps: {mcts_steps:.1f}")

print("\nRandom:")
random_wins, random_steps = test_algorithm_performance(
    NoccaNocca, RandomAgent, {}, episodes=5
)
print(f"  Wins: {random_wins}/5, Avg steps: {random_steps:.1f}")

print("\n¡Comparación completada!")
